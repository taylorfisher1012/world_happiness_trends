# %% [markdown]
# World Happiness Report from the Gallup World Poll

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
happiness_report = pd.read_csv('../data/world_happiness_report.csv')

# %%
happiness_report.dtypes
# Out:
# Country name                         object
# year                                  int64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %%
happiness_report
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
happiness_report.sort_values(by='Life Ladder', ascending=False).head(20)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 505       Denmark  2005        8.019              10.849           0.972
# 507       Denmark  2008        7.971              10.878           0.954
# 635       Finland  2020        7.889              10.767           0.962
# 633       Finland  2018        7.858              10.780           0.962
# 506       Denmark  2007        7.834              10.889           0.954
# 636       Finland  2021        7.794              10.795           0.970
# 632       Finland  2017        7.788              10.770           0.964
# 510       Denmark  2011        7.788              10.845           0.962
# 634       Finland  2019        7.780              10.791           0.937
# 1868  Switzerland  2012        7.776              11.107           0.947
# 509       Denmark  2010        7.771              10.836           0.975
# 637       Finland  2022        7.729              10.814           0.974
# ...

# %%
happiness_report.sort_values(by='Life Ladder', ascending=True).head(20)
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 13                 Afghanistan  2022        1.281                 NaN
# 1116                   Lebanon  2021        2.179               9.471
# 1117                   Lebanon  2022        2.352               9.428
# 11                 Afghanistan  2019        2.375               7.640
# 12                 Afghanistan  2021        2.436               7.324
# 1709              Sierra Leone  2022        2.560               7.401
# 1115                   Lebanon  2020        2.634               9.531
# 9                  Afghanistan  2017        2.662               7.648
# 1883                     Syria  2013        2.688               8.419
# 347   Central African Republic  2016        2.693               6.707
# 10                 Afghanistan  2018        2.694               7.631
# 2195                  Zimbabwe  2019        2.694               7.698
# ...

# %%
plt.scatter('Life Ladder', 'Log GDP per capita', data = happiness_report)
plt.xlabel('Happiness (score 0-10)')
plt.ylabel('Log GDP per Capita')
plt.title('GDP per capita vs. Happiness');

# %%
plt.scatter('Life Ladder', 'Healthy life expectancy at birth', data = happiness_report)
plt.xlabel('Happiness (score 0-10)')
plt.ylabel('Healthy life expectancy at birth (%)')
plt.title('Healthy life expectancy vs. Happiness');

# %%
happiness_report.sort_values(by='Healthy life expectancy at birth', ascending=True).head(50)
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 766                      Haiti  2006        3.754               7.973
# 767                      Haiti  2008        3.846               8.012
# 768                      Haiti  2010        3.766               7.984
# 769                      Haiti  2011        4.845               8.022
# 770                      Haiti  2012        4.413               8.012
# 2182                  Zimbabwe  2006        3.826               7.460
# 344   Central African Republic  2007        4.160               6.946
# 1118                   Lesotho  2011        4.898               7.785
# 2183                  Zimbabwe  2007        3.280               7.413
# 1119                   Lesotho  2016        3.808               7.897
# 345   Central African Republic  2010        3.568               7.031
# 610                   Eswatini  2011        4.867               8.902
# ...

# %%
plt.scatter('Life Ladder', 'Freedom to make life choices', data = happiness_report)
plt.xlabel('Happiness score 0-10)')
plt.ylabel('Freedom to make life choices')
plt.title('Freedom to make life choices vs. Happiness');

# %%
#Not a clear trend between life ladder and generosity
plt.scatter('Life Ladder', 'Generosity', data = happiness_report)
plt.xlabel('Life Ladder (score 0-10)')
plt.ylabel('Generosity')
plt.title('Generosity vs. Happiness');

# %%
us = happiness_report.loc[(happiness_report['Country name'] == 'United States')]
plt.scatter('year', 'Life Ladder', data = us, c='magenta')

finland = happiness_report.loc[(happiness_report['Country name'] == 'Finland')]
plt.scatter('year', 'Life Ladder', data = finland, c='green')
plt.xlabel('Year')
plt.ylabel('Happiness Index')
plt.title('Happiness Index by year for the United States')
plt.legend(('United States', 'Finland'))
plt.show();

# %%
us.sort_values(by='Life Ladder', ascending=True)
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 2087  United States  2022        6.693              11.079           0.900
# 2081  United States  2016        6.804              10.985           0.897
# 2080  United States  2015        6.864              10.976           0.904
# 2083  United States  2018        6.883              11.024           0.904
# 2084  United States  2019        6.944              11.043           0.917
# 2086  United States  2021        6.959              11.061           0.920
# 2082  United States  2017        6.992              11.001           0.921
# 2077  United States  2012        7.026              10.930           0.903
# 2085  United States  2020        7.028              11.005           0.937
# 2076  United States  2011        7.115              10.914           0.922
# 2079  United States  2014        7.151              10.956           0.902
# ...

# %%
plt.scatter('year', 'Life Ladder', data = happiness_report)
plt.xlabel('Year')
plt.ylabel('Happiness Index')
plt.title('Happiness Index by year');

# %%
report2008 = happiness_report.loc[happiness_report['year'] == 2008]

# %%
report2008.sort_values(by='Life Ladder', ascending = False).head(10)
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 507         Denmark  2008        7.971              10.878           0.954
# 624         Finland  2008        7.671              10.796           0.951
# 1474         Norway  2008        7.632              11.060           0.936
# 1382    Netherlands  2008        7.631              10.894           0.944
# 894         Ireland  2008        7.568              10.939           0.983
# 1851         Sweden  2008        7.516              10.778           0.923
# 329          Canada  2008        7.486              10.733           0.939
# 1398    New Zealand  2008        7.381              10.542           0.944
# 1798          Spain  2008        7.294              10.577           0.948
# 2073  United States  2008        7.280              10.923           0.953
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 507                              68.96                         0.970
# ...

# %%
#positive trend between life ladder and log GDP per capita
plt.scatter('Life Ladder', 'Log GDP per capita', data = report2008)

# %%
#Relativly positive trend between life ladder and healthy life expectancy at birth
plt.scatter('Life Ladder', 'Healthy life expectancy at birth', data = report2008)

# %%
#Relatively positive trend for life ladder and freedom to make life choices
plt.scatter('Life Ladder', 'Freedom to make life choices', data = report2008)

# %%
#No clear trend between life ladder and generosity
plt.scatter('Life Ladder', 'Generosity', data = report2008)

# %%
happiness_report
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
top_by_year = happiness_report.groupby('year').max('Life Ladder').reset_index()
top_country = top_by_year.merge(happiness_report, on='Life Ladder', how='inner')
top_country
top_country = top_country[['Country name', 'year_x', 'Life Ladder', 'Log GDP per capita_x', 'Social support_x', 'Healthy life expectancy at birth_x', 'Freedom to make life choices_x', 'Generosity_x','Perceptions of corruption_x']]
top_country_ct = top_country.groupby('Country name').count().reset_index()
top_country_ct = top_country_ct.sort_values('year_x', ascending=False)
color = ['b','green','r','m','orange']
plt.bar('Country name', 'year_x', data = top_country_ct, color=color)
plt.xlabel('Country')
plt.ylabel('Number of years')
plt.title('Happiness Index score winners from 2005-2022');
#top_country

# %%
top_country
# Out:
#    Country name  year_x  Life Ladder  Log GDP per capita_x  Social support_x  \
# 0       Denmark    2005        8.019                10.849             0.979
# 1       Finland    2006        7.672                11.433             0.970
# 2       Denmark    2007        7.834                11.212             0.970
# 3       Denmark    2008        7.971                11.177             0.983
# 4       Denmark    2009        7.683                11.628             0.964
# 5       Denmark    2010        7.771                11.647             0.976
# 6       Denmark    2011        7.788                11.635             0.977
# 7       Finland    2011        7.788                11.635             0.977
# 8       Denmark    2017        7.788                11.653             0.967
# 9       Finland    2017        7.788                11.653             0.967
# 10  Switzerland    2012        7.776                11.627             0.979
# ...

# %%
days_off = pd.read_csv('days_off.csv')
days_off
# Out:
#      Unnamed: 0      Country  \
# 0             0  Afghanistan
# 1             1      Albania
# 2             2      Algeria
# 3             3      Andorra
# 4             4       Angola
# ..          ...          ...
# 201         201    Venezuela
# 202         202      Vietnam
# 203         203        Yemen
# 204         204       Zambia
# 205         205     Zimbabwe
#
#                                   Minimum annual leave  \
# 0    Employees are entitled to 20 days recreational...
# 1    Employees are entitled to 28 days of annual le...
# 2    The paid annual leave is calculated on the bas...
# 3    Workers are entitled to 31 calendar days of pa...
# 4    The annual leave for workers is 22 days, not i...
# ..                                                 ...
# 201  Workers are entitled to enjoy 15 days of paid ...
# 202  Employees working in normal working conditions...
# 203  Workers shall be entitled to leave of not less...
# ...

# %%
happiness_days_off = happiness_report.merge(days_off, left_on ='Country name', right_on = 'Country', how='inner')
happiness_days_off
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2067     Zimbabwe  2018        3.616               7.783           0.775
# 2068     Zimbabwe  2019        2.694               7.698           0.759
# 2069     Zimbabwe  2020        3.160               7.596           0.717
# 2070     Zimbabwe  2021        3.155               7.657           0.685
# 2071     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
days_off['Total paid leave (five-day workweek)'].max()
# Out:
# 53.0

# %%
days_off = happiness_days_off.rename(columns={'Total paid leave (five-day workweek)':'Num_days'})
days_off
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2067     Zimbabwe  2018        3.616               7.783           0.775
# 2068     Zimbabwe  2019        2.694               7.698           0.759
# 2069     Zimbabwe  2020        3.160               7.596           0.717
# 2070     Zimbabwe  2021        3.155               7.657           0.685
# 2071     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
days = days_off[['Life Ladder', 'Num_days']]
days.corr()
# Out:
#              Life Ladder  Num_days
# Life Ladder     1.000000 -0.110789
# Num_days       -0.110789  1.000000

# %%
days_off.loc[days_off['Num_days'].idxmax()].to_frame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 days_off.loc[days_off['Num_days'].idxmax()].to_frame()
#
# NameError: name 'days_off' is not defined

# %%
more_than40 = days_off.loc[days_off['Num_days'] > 40]
count_more_than40 = more_than40['Num_days'].count()
count_more_than40
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 more_than40 = days_off.loc[days_off['Num_days'] > 40]
#       2 count_more_than40 = more_than40['Num_days'].count()
#       3 count_more_than40
#
# NameError: name 'days_off' is not defined

# %%
more_than30 = days_off.loc[(days_off['Num_days'] > 30) & (days_off['Num_days'] < 40)]
count_more_than30 = more_than30['Num_days'].count()
count_more_than30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 more_than30 = days_off.loc[(days_off['Num_days'] > 30) & (days_off['Num_days'] < 40)]
#       2 count_more_than30 = more_than30['Num_days'].count()
#       3 count_more_than30
#
# NameError: name 'days_off' is not defined

# %%
more_than20 = days_off.loc[(days_off['Num_days'] > 20) & (days_off['Num_days'] < 30)]
count_more_than20 = more_than20['Num_days'].count()
count_more_than20

# %%
more_than10 = days_off.loc[(days_off['Num_days'] > 10) & (days_off['Num_days'] < 20)]
count_more_than10 = more_than10['Num_days'].count()
count_more_than10

# %%
more_than0 = days_off.loc[(days_off['Num_days'] >= 0) & (days_off['Num_days'] < 10)]
count_more_than0 = more_than0['Num_days'].count()
count_more_than0

# %%
days_off_count = [count_more_than40, count_more_than30, count_more_than20, count_more_than10, count_more_than0]

labels= '40+', '30-40', '20-30', '10-20', '0-10'

fit, ax = plt.subplots()
ax.pie(days_off_count, labels = labels,
        shadow=True, startangle=90)
plt.title('Number of days paid leave');

# %%
happiness_days_off = happiness_days_off.rename(columns={'Total paid leave (five-day workweek)':'Num_days'})

# %%
plt.scatter('Life Ladder', 'Num_days', data = happiness_days_off)

# %%
happiness_days_off2022 = happiness_days_off.loc[happiness_days_off['year'] == 2022]

# %%
plt.scatter('Life Ladder', 'Num_days', data = happiness_days_off2022)
plt.xlabel('Happiness (score 0-10)')
plt.ylabel('Number of paid leave')
plt.title('Paid Leave for 2022 vs. Happiness')

# %%
happiness_report['Life Ladder'].max()

# %%
happiness_days_off2022['Life Ladder']

# %%
crime = pd.read_csv('../data/crime-rate-by-country-2023.csv')

# %%
crime

# %%
crime.dtypes

# %%
crime = crime.rename(columns={'crimeRateByCountry_crimeIndex': 'crimeIndex'})

# %%
crime = crime[['place', 'pop2023', 'growthRate', 'area', 'country', 'density', 'crimeIndex']]
crime

# %%
happiness_crime = happiness_report.merge(crime, left_on ='Country name', right_on = 'country', how='inner')
happiness_crime

# %%
happiness_crime_2022 = happiness_crime.loc[happiness_crime['year'] == 2022]

# %%
happiness_crime_2022 = happiness_crime_2022.reset_index(drop =True)

# %%
plt.scatter('Life Ladder', 'crimeIndex', data = happiness_crime_2022)
plt.xlabel('Happiness (score 1-10)')
plt.ylabel('Crime Index')
plt.title('Crime Index vs Happiness')

# %%
happiness_crime_2022.sort_values(by='crimeIndex', ascending=False).reset_index(drop=True)

# %%
plt.scatter('Negative affect', 'crimeIndex', data = happiness_crime_2022)
plt.xlabel('Negative affect')
plt.ylabel('Crime Index')
plt.title('Crime Index vs Negative Affect')

# %%
happiness_crime_2022.sort_values(by='pop2023', ascending=False)

# %%
happiness_crime_2022[['Negative affect', 'crimeIndex']].corr()

# %%
plt.scatter('Healthy life expectancy at birth', 'crimeIndex', data=happiness_crime_2022)
plt.xlabel('Healthy life expectancy at birth')
plt.ylabel('Crime Index')
plt.title('Crime Index vs Healthy life expectancy at birth')

# %%
plt.scatter('Log GDP per capita', 'crimeIndex', data=happiness_crime_2022)
plt.xlabel('Log GDP per capita')
plt.ylabel('Crime Index')
plt.title('Crime Index vs Log GDP per capita')
